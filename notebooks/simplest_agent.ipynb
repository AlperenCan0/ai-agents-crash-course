# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name='Nutrition Assistant',
    instructions="""
    You are a helpful assistant giving out nutrition advice.
    You give concise answers.
"""
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Bananas are healthy and nutrient-dense.
#
#     Key points:
#     - Good source of potassium (supports blood pressure), vitamin B6, vitamin C, and dietary fiber.
#     - About 90 calories per medium banana; low fat; some natural sugar.
#     - Benefits: may help with heart health, digestion, and energy.
#
#     Considerations:
#     - If watching sugar/carbs (diabetes), factor portion size.
#     - High fiber can cause gas in some people.
#
#     Hint: pair with protein or fat (e.g., peanut butter) to slow sugar absorption. 1–2 bananas per day fits most diets.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Bananas are generally very healthy. They’re a good source of:
#
# - Potassium (heart and nerve function)
# - Vitamin B6 and vitamin C
# - Dietary fiber (helps digestion)
#
# Low in fat and versatile.
#
# Notes:
# - They contain natural sugars; portion matters if you’re watching carbs or blood sugar (a medium banana is common).
# - Unripe bananas have more resistant starch; ripe bananas are sweeter with more sugar.
# - Dried/canned varieties can have added sugar; choose fresh or unsweetened options.
#
# Overall: for most people, a medium banana a day fits a balanced diet.

# %% [markdown]
# _Good Job!_
